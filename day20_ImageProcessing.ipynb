# %%
import cv2
from skimage import io
from PIL import Image
import matplotlib.pyplot as plt

# %%
i1 = cv2.imread('virat.jpg')

# %%
type(i1)
# Out:
# numpy.ndarray

# %%
i1
# Out:
# array([[[ 79,  81,  45],
#         [ 89,  91,  55],
#         [100, 102,  66],
#         ...,
#         [ 96,  86,  52],
#         [ 93,  83,  49],
#         [ 90,  80,  46]],
#
#        [[ 79,  81,  45],
#         [ 90,  92,  56],
#         [100, 102,  66],
#         ...,
#         [ 96,  86,  52],
#         [ 93,  83,  49],
#         [ 91,  81,  47]],
#
#        [[ 80,  82,  46],
#         [ 90,  92,  56],
#         [101, 103,  67],
#         ...,
#         [ 97,  87,  53],
#         [ 94,  84,  50],
#         [ 91,  81,  47]],
#
#        ...,
#
#        [[ 51,  52,  20],
#         [ 52,  53,  21],
#         [ 55,  56,  24],
#         ...,
#         [ 69,  68,  42],
#         [ 65,  64,  38],
#         [ 63,  62,  36]],
#
#        [[ 51,  52,  20],
#         [ 52,  53,  21],
#         [ 55,  56,  24],
#         ...,
#         [ 69,  68,  42],
#         [ 65,  64,  38],
#         [ 63,  62,  36]],
#
#        [[ 51,  52,  20],
#         [ 52,  53,  21],
#         [ 55,  56,  24],
# ...

# %%
i1.shape
# Out:
# (500, 900, 3)

# %%
cv2.imshow('Virat',i1)
cv2.waitKey(0)
# Out:
# -1

# %%
i2 = io.imread('virat.jpg')
type(i2)
# Out:
# numpy.ndarray

# %%
i2
# Out:
# array([[[ 45,  81,  79],
#         [ 55,  91,  89],
#         [ 66, 102, 100],
#         ...,
#         [ 52,  86,  96],
#         [ 49,  83,  93],
#         [ 46,  80,  90]],
#
#        [[ 45,  81,  79],
#         [ 56,  92,  90],
#         [ 66, 102, 100],
#         ...,
#         [ 52,  86,  96],
#         [ 49,  83,  93],
#         [ 47,  81,  91]],
#
#        [[ 46,  82,  80],
#         [ 56,  92,  90],
#         [ 67, 103, 101],
#         ...,
#         [ 53,  87,  97],
#         [ 50,  84,  94],
#         [ 47,  81,  91]],
#
#        ...,
#
#        [[ 20,  52,  51],
#         [ 21,  53,  52],
#         [ 24,  56,  55],
#         ...,
#         [ 42,  68,  69],
#         [ 38,  64,  65],
#         [ 36,  62,  63]],
#
#        [[ 20,  52,  51],
#         [ 21,  53,  52],
#         [ 24,  56,  55],
#         ...,
#         [ 42,  68,  69],
#         [ 38,  64,  65],
#         [ 36,  62,  63]],
#
#        [[ 20,  52,  51],
#         [ 21,  53,  52],
#         [ 24,  56,  55],
# ...

# %%
i2.shape
# Out:
# (500, 900, 3)

# %%
io.imshow(i2)

# %%
i3 = plt.imread('virat.jpg')
type(i3)
# Out:
# numpy.ndarray

# %%
i3.shape
# Out:
# (500, 900, 3)

# %%
plt.imshow(i3)

# %%
i4 = Image.open('virat.jpg')

# %%
type(i4)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
i4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x500 at 0x2561FC3CBE0>

# %%
plt.imsave('new.jpg',i2)
